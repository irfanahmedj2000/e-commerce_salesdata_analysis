# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
st_df = pd.read_csv(r"D:\flipkart_data\Search_Traffic_Reports.csv")

# %%
st_df.head(5)
# Out:
#                   Listing Id             SKU Id  \
# 0  LSTZLAHM9WJMQFFADHJSKCPGK  WEEGRO-CT-TEAK-PL
# 1  LSTCFTGHEMDSHRHNZDX1P29H6              RMDF1
# 2  LSTCFTHGMJZGMGDGXZCXYDAPW  WEEGRO-CT-PLASTIC
# 3  LSTCFTGDDBYMAZQCQ8X2BLN1L       WEEGRO-CT-M1
# 4  LSTDNTHGMHSZX8GYZHKBSH5DL      WEEGRO-DINING
#
#                                        Product Title  \
# 0  WEEGRO WEEGRO Work Station Tray Furniture Acce...
# 1  WEEGRO Engineered Wood Coffee Table Finish Col...
# 2  WEEGRO Plastic Coffee Table Finish Color - Bro...
# 3  WEEGRO Engineered Wood Coffee Table Finish Col...
# 4  WEEGRO Plastic 4 Seater Dining Table Finish Co...
#
#                     Category   Brand            Vertical Impression Date  \
# 0  GeneralUtilityFurnitureSF  WEEGRO  FurnitureAccessory      2026-05-31
# 1               LivingRoomSF  WEEGRO   SmallCoffeeTables      2026-05-31
# 2               LivingRoomSF  WEEGRO   SmallCoffeeTables      2026-05-31
# ...

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Listing Id             74 non-null     object
#  1   SKU Id                 74 non-null     object
#  2   Product Title          74 non-null     object
#  3   Category               74 non-null     object
#  4   Brand                  74 non-null     object
#  5   Vertical               74 non-null     object
#  6   Impression Date        74 non-null     object
#  7   Revenue                74 non-null     float64
#  8   Product Views          74 non-null     int64
#  9   Product Clicks         74 non-null     int64
#  10  Sales                  74 non-null     int64
#  11  Click Through Rate     74 non-null     float64
#  12  Conversion Rate        74 non-null     float64
#  13  Average Selling Price  74 non-null     float64
# dtypes: float64(4), int64(3), object(7)
# ...

# %%
st_df.shape
# Out:
# (74, 14)

# %%
st_df.isnull().sum()
# Out:
# Listing Id               0
# SKU Id                   0
# Product Title            0
# Category                 0
# Brand                    0
# Vertical                 0
# Impression Date          0
# Revenue                  0
# Product Views            0
# Product Clicks           0
# Sales                    0
# Click Through Rate       0
# Conversion Rate          0
# Average Selling Price    0
# dtype: int64

# %%
st_df.rename(columns={
'Listing Id':'listing_id',               
'SKU Id':'sku_id',               
'Product Title':'product_title',         
'Category':'category'   ,              
'Brand':'brand'    ,            
'Vertical':'vertical'  ,               
'Impression Date':'impression-date'   ,       
'Revenue':'revenue'   ,               
'Product Views':'product_views',           
'Product Clicks':'product_clicks',           
'Sales':'sales',                    
'Click Through Rate':'click_through_rate',       
'Conversion Rate':'conversion_rate',          
'Average Selling Price':'average_selling_price'    
}, inplace=True)

# %%
st_df['impression-date']=pd.to_datetime(st_df['impression-date'])

# %%
st_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
st_df.to_csv(
    r"D:\flipkart_data\data\cleaned\cleaned_search_data.csv",
    index=False
)

# %%
from sqlalchemy import create_engine
import pandas as pd
username="postgres"
password="irfan123"
host="localhost"
port="5432"
database="sales_analysis"
engine=create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
table_name="search_traffic"
st_df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Data successfully loaded into the table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into the table 'search_traffic' in database 'sales_analysis'.

# %%
|
